# %%
import requests
from bs4 import BeautifulSoup
import os
import re

# SITEMAP_URL = "https://www.davidkolbconsultancy.com/pages-sitemap.xml"

SITEMAP_URL = "https://www.davidkolbconsultancy.com/pages-sitemap.xml"

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36"
}
OUTPUT_DIR = "downloaded_pages"

# Ensure output directory exists
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

# Fetch the sitemap content
sitemap_response = requests.get(SITEMAP_URL, headers=HEADERS)
sitemap_soup = BeautifulSoup(sitemap_response.content, 'xml')

# Extract URLs from the sitemap
urls = [loc.text for loc in sitemap_soup.find_all("loc")]

# Fetch content of each URL and save to a separate text file
for url in urls:
    response = requests.get(url, headers=HEADERS)
    page_soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract the title from the HTML
    title_tag = page_soup.find("title")
    if title_tag:
        title = title_tag.get_text(strip=True)
    else:
        title = "Untitled"  # Use a default title if no <title> tag is found
    
    # Additional text to be added at the end of the file
    additional_text = '"'
    
    # Extract text content from the HTML and remove consecutive blank lines
    text_content = page_soup.get_text(separator='\n').strip()
    text_content = re.sub(r'\n{2,}', '\n\n', text_content)
    
    print(text_content)

    # Create a filename based on the URL
    filename = url.rstrip('/').split('/')[-1] or "index"
    filepath = os.path.join(OUTPUT_DIR, f"{filename}.txt")
    
    with open(filepath, 'w', encoding="utf-8") as file:
        # Write the title and additional text to the file
        file.write("Page Title : " + '"' + title)
        file.write(text_content + "\n")
        file.write(additional_text)
    
    print(f"Saved content of {url} to {filepath}")
# Out:
# David Kolb - Human-Centric Innovation Consultant
#
# top of page
# Home
# Coaching
# Consulting
# Blog
# About
# Contact
# More
# Use tab to navigate through the menu items.
# Sustainable Innovation and Transformation
# We specialise in tackling complex challenges with actionable strategies
# Book a 1:1 Call
#
# Experienced in working with some of the best
# People are the Heart of Business.
#
# We Guide You to Innovate with Empathy in Uncertain Times
# Solutions Rooted in Human Needs – That's Real Innovation
# We prioritise human experiences, using AI to swiftly adapt to and meet genuine human needs amidst chaos
# Revolutionise with Intelligent Resourcefulness
# From innovation to impact, we challenge traditional mindsets to give you an edge that’s both creatively human and technologically advanced
# Decades of Expertise, Refined for Practical Innovation
# Our breadth and depth of expertise are refined across diverse economic landscapes, ensuring our ideas are strategic yet customisable to your means.
# Strengthen Your Business with Pragmatic Strategies
# We focus on actionable results at the intersection of creative, business, and technology expertise, ensuring every solution is human centred.
# Book a 1:1 Call
#
# Our Offerings. Tailored to Your Ambitions
# Empower Your Potential with Bespoke Coaching
# Hone your creative thinking and leadership skills in our coaching sessions. Learn tools and AI to nurture a growth mindset, navigate change, and maximise performance
# Transform Your Business with Strategic Partnerships
# We partner to create practical, impactful solutions, aligning human centred principles with AI-driven insights to construct a roadmap for innovation and execution through volatility.
# Seeking a Business Breakthrough? Start with Our Complimentary Strategy Session
# Book a 1:1 Call
#
# Navigating Change With Confidence
# Turn Uncertainty into Your Competitive Advantage
# Uncertainty is where we excel. Together, we'll build strategies aligned to your ambitions, ensuring you adapt and thrive amidst change
# Fuel Sustainable Growth with Insight-Driven Innovation
# Leverage our knowledge and creative thinking to steer your business toward expansion. We support informed risk-taking that lifts your market position
# Cultivate Lasting Agility and Resilience
# Embrace every challenge as a catalyst for innovation. With our partnership, you foster a culture of resilience and unlock your team's and business's full potential.
# Let's explore the transformative steps we can take together to secure your business's future.
# Book a 1:1 Call
#
# Our Comprehensive Process: From Insight to Impact
# Customisation at Every Phase. We anticipate needs by blending design, business, and AI capabilities to provide a service as unique as your challenges.
# 01 Problem Framing Mastery
#
# We help your team develop skills to frame problems effectively, identifying the right problems to solve. Our focus is on finding creative solutions to real challenges
#
# 03 Ideating with Purpose
#
# 02 Strategy with Empathy
# At the strategic core, we centre on people — your customers, staff, and stakeholders. We embed this human-first approach into your capabilities, shaping strategies that resonate and deliver
# Harnessing AI, we elevate your human-centric strategy into actionable solutions. Creativity meets intent—each concept is crafted to transform customer-centric visions into reality.
#
# 04 Prototyping & Testing
# 05 Engaging Storytelling
#
# Beyond creating, we iterate — facilitating a space for testing and refining prototypes. It's a step that encourages a mindset of agile, continuous enhancement
# We help articulate your vision into compelling narratives that connect with your audience, elevate your pitch, and capture the true essence of your innovation
#
# 06 Executing with Excellence
# Our goal is your success. We help shape the Execution Plan, Maintain Momentum and Deliver Measurable Impact.
# Ready to turn strategic vision into operational reality? Let's talk execution.
# Book a 1:1 Call
#
# Home
# Coaching
# Consulting
# Blog
# About
# Contact
# More
# Use tab to navigate through the menu items.
# david@davidkolbconsultancy.com
#  © 2023 David Kolb Consultancy | All rights reserved |
# Privacy policy
# bottom of page
# Saved content of https://www.davidkolbconsultancy.com to downloaded_pages/www.davidkolbconsultancy.com.txt
# About David Kolb - Business Innovation Consultant
#
# top of page
# Home
# Coaching
# Consulting
# Blog
# About
# Contact
# More
# Use tab to navigate through the menu items.
# Who we are
# We're here to help visionary leaders and entrepreneurs shape their future
# We equip leaders with insights and partnerships to seize opportunities and navigate uncertainty.
# Book a 1:1 Call
#
# Our Story.
# Since the beginning, our mission has been helping organisations innovate and transform through human-centred, technology-enabled solutions.
#
# ​
#
# As Artificial Intelligence
#  transforms industries, we knew a new strategic approach was needed. We blended creativity, business, and technology expertise into an integrated methodology that puts people at the centre of progress.
# Our Foundations.
# Leveraging our journey of pioneering business strategies, evolving tech and human-centric design, we blend real-world expertise to enable transformation.
# Our differentiator.
# With human-centred insights, visionary leadership, and expertise in technological innovation and Artificial Intelligence, we empower purposeful transformation.
# Humanity in Innovation.
# Our people focused strategies deliver resonant solutions that achieve real business impact. We leverage Artificial Intelligence insights while keeping people at the core.
# What drives us?
# Our founder, David Kolb's, extensive experience enables our human-centred approach. His passion for technology and creative leadership empowers our purpose. With a history of collaboration with industry leaders like HSBC, LQID, N Brown, Toys 'R' Us, and Compass Group, David's
# diverse experience
#  powers our purpose-driven services.
# Innovating Through Partnership.
# We tap collective creativity, diverse perspectives, and Artificial Intelligence to reframe problems and uncover opportunities. By collaborating closely with clients and leveraging our AI capabilities, we co-create tailored solutions and empower inspired teams.
# Our Values
# Be Creative.
#  We tackle obstacles head-on, meeting challenges with imagination to uncover innovative solutions.
#
# ​
# ​
#
# Be Different.
# Our blend of business, technology, and collaboration drives new ways of strategic thinking.
#
# ​
#
# Be Empathetic.
# With empathy at our core, we first understand people's needs to develop tailored, impactful strategies.
#
# ​
#
# Empower Others.
# We equip clients with tools to unlock potential, driven by our passion to see organisations and people thrive.
#
# ​
#
# Believe.
# Our hands-on, can-do attitude fosters an environment where ground breaking ideas flourish.
# Realise your potential - start your innovation journey today.
# Book a 1:1 Call
#
# Home
# Coaching
# Consulting
# Blog
# About
# Contact
# More
# Use tab to navigate through the menu items.
# david@davidkolbconsultancy.com
#  © 2023 David Kolb Consultancy | All rights reserved |
# Privacy policy
# bottom of page
# Saved content of https://www.davidkolbconsultancy.com/about to downloaded_pages/about.txt
# David Kolb's Blog - Business Innovation Insights
#
# top of page
# Home
# Coaching
# Consulting
# Blog
# About
# Contact
# More
# Use tab to navigate through the menu items.
# Insightful blogs on business innovation, creative problem solving and technology
# Book a 1:1 Call
#
# All Posts
# Case Studies
# Artificial Intelligence
# Digital Banking
# Business Innovation
# Strategy
# Design Thinking
# Human-Centered Design
# Leadership
# Quick Tips
# Product Design
# David Kolb
# Oct 29
# 3 min
# Implementing Problem Solving: Strategic Approaches and Techniques for Organisational Growth
# Today's corporate landscape is as promising as it is challenging. With evolving business models and market dynamics, there's a premium on...
# 2 views
# David Kolb
# Oct 29
# 2 min
# Understanding Problem Solving: Definitions, Descriptions, and Implications for Leadership
# In the evolving landscape of personal and professional environments, understanding the essence of problem solving is pivotal. But what...
# 4 views
# David Kolb
# Oct 29
# 3 min
# Design Thinking 101: The Ultimate Toolbox for Business Innovation
# In the ever-evolving landscape of the modern business world, staying innovative is not just an advantage; it's a necessity. Enter Design...
# 4 views
# 1
# 2
# 3
# 4
# 5
# Book a 1:1 Call
#
# Home
# Coaching
# Consulting
# Blog
# About
# Contact
# More
# Use tab to navigate through the menu items.
# david@davidkolbconsultancy.com
#  © 2023 David Kolb Consultancy | All rights reserved |
# Privacy policy
# bottom of page
# Saved content of https://www.davidkolbconsultancy.com/blog to downloaded_pages/blog.txt
# David Kolb's Design Thinking Coaching for Leaders
#
# top of page
# Home
# Coaching
# Consulting
# Blog
# About
# Contact
# More
# Use tab to navigate through the menu items.
# Navigate Complexity with Confidence
# Developing Strategic Leaders
# Experience hands-on coaching tailored to guide you through challenges with clarity and strategic foresight.
# Book a 1:1 Call
#
# Unlock the Transformative Power of a Human Centered Approach
# Our approach is pragmatic, personalised, and oriented on clear objectives - developing you into an agile, forward-thinking leader ready to thrive in an unpredictable business landscape.
# Targeted Outcomes
#
# Solve complex problems with creative, innovative solutions
#
# Deeply understand yourself and your leadership style
#
# Enable informed decision making that maximises personal impact
#
# Foster collaboration across functions focused on tangible results
#
# Cultivate emotional resilience, agility and a growth mindset
#
# Accelerate your capabilities in AI adoption and integration
#
# Book a 1:1 Call
#
# Coaching for Results
# Strategic Innovation Coaching
#
# Accelerate skills to rapidly ideate, pivot strategies, and adopt human-centric AI capabilities.
# Resilient Leadership Coaching
#
# Cultivate agility and resilience to lead confidently amid constant change and AI disruption.
# Business Growth Coaching
#
# Guide technology integration, performance gains, and strategic vision to capitalise on new opportunities
# .
# Book a 1:1 Call
#
# Get Started with a Complimentary Session
#
# Initiate with a discovery session, aligning on clear objectives.
#
# Receive a personalised coaching roadmap tailored to your needs.
#
# Accelerate your success through focused coaching on tangible outcomes.
#
# What People Say About David's Coaching
# David's sessions excel in both depth and precision. People love his proactive approach, which ensures you get the most out of each moment, offering insights that lead to transformative 'Aha!' experiences. Many find ourselves wishing for even more time, a testament to the invaluable nature of his sessions.
# David's ability to truly listen sets his coaching apart. People love his unique knack for guiding them past challenges, furnishing actionable insights, and offering additional resources for our continued growth. His sessions aren't just engaging; they're a crucial part of the learning journey.
# With an impeccable blend of clarity and depth, David imparts a refined understanding of organisational strategies. His collaborative approach, complemented by tangible examples, always leaves people invigorated and with a renewed sense of purpose.
# Schedule Your Complimentary Coaching Discovery Call Today
# Book a 1:1 Call
#
# Home
# Coaching
# Consulting
# Blog
# About
# Contact
# More
# Use tab to navigate through the menu items.
# david@davidkolbconsultancy.com
#  © 2023 David Kolb Consultancy | All rights reserved |
# Privacy policy
# bottom of page
# Saved content of https://www.davidkolbconsultancy.com/coaching to downloaded_pages/coaching.txt
# David Kolb's Innovation & Strategic Growth Consulting
#
# top of page
# Home
# Coaching
# Consulting
# Blog
# About
# Contact
# More
# Use tab to navigate through the menu items.
# Discover New Horizons by Daring to Think Differently
# Realise Your Full Potential Through Strategic Innovation
# Leverage customised guidance and emerging technologies to unlock new opportunities and accelerate your organisation's growth
# Book a 1:1 Call
#
# Innovating with Purpose in Times of Uncertainty
# I offer more than advice - I enable transformation. My blend of strategic foresight, human-centred innovation, and technology mastery provides unique guidance amidst complexity
# Expertly Guided Transition.
#  With years of experience, I offer tailored plans to help you gain competitive advantage and confidently navigate change and Artificial Intelligence disruption
#
#
#
# Building Resilient Growth.
# We craft custom strategies focused on fuelling sustainable innovation and unlocking long-term expansion
#
#
#
# Human-Focused Innovation.
# Our collaborative process puts people first, combining human insights with Artificial Intelligence to create value and drive growth
#
# ​
#
# Intelligent Technology Integration.
#  We provide strategic guidance on leveraging emerging tech like Artificial Intelligence to optimise operations and accelerate growth
# Book a 1:1 Call
#
# Discover the Suite of Services Designed to Catapult Your Business Forward
# Business Model Innovation Sprints
#
# Reimagine your business model through an intensive hands-on sprint. We combine actionable frameworks, prototyping, and mentorship to enable transformative outcomes
# AI & Emerging Tech Integration
#
# Harness the potential of AI and cutting-edge technologies. With assessment, design, prototyping, and road mapping, we identify high-impact ideas to accelerate your digital capabilities
# Innovation Acceleration Program
#
# Our 12-week program enables you to tackle complex challenges. With human-centric design at the core, this comprehensive engagement imparts the tools and mindsets to drive strategic transformation
# Book a 1:1 Call
#
# Why choose me?
#
# Hands-on Guidance from Vision to Execution
#
# Adaptive Strategies for Sustainable Results
#
# A Collaborative, Growth-Focused Culture
#
# Deep Knowledge of Artificial Intelligence
#
# Ongoing Support for Continual Innovation
#
# Let's discuss how my integrated strategic approach can empower your organisation's evolution
# Schedule Your Free Consultation Now
# Book a 1:1 Call
#
# Home
# Coaching
# Consulting
# Blog
# About
# Contact
# More
# Use tab to navigate through the menu items.
# david@davidkolbconsultancy.com
#  © 2023 David Kolb Consultancy | All rights reserved |
# Privacy policy
# bottom of page
# Saved content of https://www.davidkolbconsultancy.com/consulting to downloaded_pages/consulting.txt
# Contact David Kolb's Consultancy
#
# top of page
# Home
# Coaching
# Consulting
# Blog
# About
# Contact
# More
# Use tab to navigate through the menu items.
# The Future Belongs to the Curious
# In today's rapidly changing landscape, success requires embracing deep curiosity, creativity and continuous learning
# I draw on decades of experience guiding organisations through disruption. My approach integrates strategic foresight, human centred design, and emerging technologies like Artificial Intelligence to provide tailored guidance based on your unique vision and challenges.
# Book a 1:1 Call
#
# Alternatively, Leave Us a Message
# Name
# Email
# How did you find us?
# Your message
# Send
# Thanks for submitting!
# Home
# Coaching
# Consulting
# Blog
# About
# Contact
# More
# Use tab to navigate through the menu items.
# david@davidkolbconsultancy.com
#  © 2023 David Kolb Consultancy | All rights reserved |
# Privacy policy
# bottom of page
# Saved content of https://www.davidkolbconsultancy.com/contact to downloaded_pages/contact.txt
# Privacy Policy | David Kolb Consultancy
#
# top of page
# Home
# Coaching
# Consulting
# Blog
# About
# Contact
# More
# Use tab to navigate through the menu items.
# Website Privacy Policy
# Welcome to David Kolb Consultancy. We respect your right to privacy. We are a private limited company registered in England and Wales under company number 12870554 and have our registered office at 143 Station Road, Hampton, Middlesex, England, TW12 2AL.
#
#
#
# Please direct any inquiries to
# admin@davidkolbconsultancy.com
# .
#
#
#
# The personal information we collect and how we use it
#
# We currently collect and process the following information:
#
# Personal identifiers, contacts, and characteristics (for example, name and contact details)
#
# Internet protocol (IP) address used to connect your computer to the Internet.
#
# Login, email address, password, computer and connection information, and purchase history
#
# Session information, including page response times, length of visits to certain pages, page interaction information, and methods used to browse away from the page.
#
# Personally identifiable information (including name, email, password, communications)
#
# Comments, feedback, product reviews, recommendations, and personal profile.
#
#
#
# How we obtain the personal information and why we process it
#
# Most of the personal information we process is provided to us directly by you for one or more of the following reasons:
#
# To provide and operate our services.
#
# To offer ongoing customer assistance and technical support.
#
# To contact our visitors and users with general or personalised service-related notices and promotional messages.
#
# To create aggregated statistical data and other aggregated and/or inferred non-personal information, which we or our business partners may use to provide and improve our respective services.
#
# To comply with any applicable laws and regulations.
#
#
#
# Legal bases for processing personal information
#
# We process your personal information under one or more of the following legal bases:
#
# (a) Your consent, which you can withdraw at any time by contacting
# admin@davidkolbconsultancy.com
#
# (b) Our contractual obligations
#
# (c) Our legal obligations
#
# (d) Vital interests
#
# (e) Performance of public tasks
#
# (f) Legitimate interests
#
#
#
# Data retention
#
# We retain your information as needed to fulfill statutory, contractual, and data controller obligations. Personal data retention periods are based on the following criteria:
#
#
#
# Queries: Retained as necessary for addressing queries effectively.
#
# Legal and regulatory requirements: Retained for 7 years after account closure or service termination, and may be used to defend legal claims.
#
#
#
# How we store your personal information
#
# Your information is securely stored. Our company is hosted on the Wix.com platform, which provides us with the online platform that allows us to sell our products and services to you. Your data may be stored through Wix.com’s data storage, databases, and general applications. They store your data on secure servers behind a firewall.
#
#
#
# We use Google Workspace for Business to manage our email communication. By contacting us via email, you acknowledge that your data may be processed and stored by Google's services in accordance with Google's Privacy Policy. For more information on how Google handles your data, please visit:
# https://policies.google.com/privacy
#
#
#
# Your data protection rights
#
# Under data protection law, you have rights including:
#
# Right of access: You have the right to request copies of your personal information.
#
# Right to rectification: You have the right to request that we correct any inaccurate personal information or complete any incomplete information.
#
# Right to erasure: You have the right to request that we erase your personal information in certain circumstances.
#
# Right to restriction of processing: You have the right to request that we restrict the processing of your personal information in certain circumstances.
#
# Right to object to processing: You have the right to object to the processing of your personal information in certain circumstances.
#
# Right to data portability: You have the right to request that we transfer the personal information you provided to us to another organisation, or to you, in certain circumstances.
#
#
#
# Please contact us at
# admin@davidkolbconsultancy.com
#  if you wish to make a request.
#
#
#
# Changes to our privacy policy
#
# We reserve the right to modify this privacy policy at any time. Changes will be posted on our website, and we encourage you to review the policy periodically to stay informed about how we process your personal information.
#
#
#
# How to complain
#
# If you have any concerns about our use of your personal information, you can make a complaint to us at
# admin@davidkolbconsultancy.com
# .
#
#
#
# You can also complain to the ICO if you are unhappy with how we have used your data. The ICO's contact details are: Helpline number: 0303 123 1113. ICO website:
# https://www.ico.org.uk
# Home
# Coaching
# Consulting
# Blog
# About
# Contact
# More
# Use tab to navigate through the menu items.
# david@davidkolbconsultancy.com
#  © 2023 David Kolb Consultancy | All rights reserved |
# Privacy policy
# bottom of page
# Saved content of https://www.davidkolbconsultancy.com/website-privacy-policy to downloaded_pages/website-privacy-policy.txt
